# %%
import pandas as pd

# ---- Bước 1: Config ----
fps = 30  # Số khung hình trên giây của video

# ---- Bước 2: Hàm chuyển đổi time → frame ----
def time_to_frame(time_str: str, fps: int) -> int:
    """
    Chuyển thời gian dạng "HH:MM:SS,mmm" thành chỉ số frame (zero‑based).
    Ví dụ: "00:41:26,000" tại 30 FPS → (41*60 + 26)*30 = 74580.
    """
    h, m, s_ms = time_str.split(':')
    s, ms = s_ms.split(',')
    total_seconds = int(h) * 3600 + int(m) * 60 + int(s) + int(ms) / 1000.0
    return int(total_seconds * fps)


# ---- Bước 3: Đọc file CSV ----
# Keypoint CSV phải có cột 'frame_id' (giá trị frame gốc)
df_keypoint = pd.read_csv("video_1.csv")

# Timeline CSV
df_timeline = pd.read_csv(r"C:\Users\Admin\Downloads\ISAS\Train Data\timetable\csv\1.csv", encoding="utf-8-sig")
df_timeline.rename(columns=lambda x: x.strip(), inplace=True)  # strip BOM/whitespace


# ---- Bước 4: Cắt theo giá trị frame_id ----
cut_segments = []

for idx, row in df_timeline.iterrows():
    start_time = row["Start Time"]
    end_time   = row["End Time"]
    label      = row["Text"]

    # Chuyển time → chỉ số frame
    start_f = time_to_frame(start_time, fps)
    end_f   = time_to_frame(end_time, fps)

    # Lọc tất cả bản ghi có frame_id trong [start_f, end_f]
    mask = (df_keypoint["frame_id"] > start_f) & (df_keypoint["frame_id"] <= end_f)
    segment = df_keypoint.loc[mask].copy()

    if segment.empty:
        print(f"⚠️ Timeline {idx}: Không có frame_id nào trong khoảng {start_f}→{end_f} ({label})")
        continue

    # Gắn cột Timeline_Label
    segment["Action Label"] = label
    cut_segments.append(segment)

    print(f"✅ Cắt timeline {idx}: {label} | frame_id {start_f} → {end_f} ({len(segment)} dòng)")


# ---- Bước 5: Gộp và lưu kết quả ----
if cut_segments:
    df_cut = pd.concat(cut_segments, ignore_index=True)
    df_cut.to_csv("keypoints_cut_by_frame_id_1.csv", index=False)
    print(f"\n✅ Đã lưu tổng cộng {len(df_cut)} dòng vào file: keypoints_cut_by_frame_id.csv")
else:
    print("❌ Không có đoạn nào được cắt! Vui lòng kiểm tra lại timeline và frame_id.")
# Out:
# ✅ Cắt timeline 0: Walking | frame_id 0 → 7350 (7350 dòng)
# ✅ Cắt timeline 1: Head banging | frame_id 7440 → 9420 (1980 dòng)
# ✅ Cắt timeline 2: Sitting quietly | frame_id 9540 → 16650 (7110 dòng)
# ✅ Cắt timeline 3: Biting | frame_id 16740 → 19410 (2670 dòng)
# ✅ Cắt timeline 4: Using phone | frame_id 19860 → 25410 (5550 dòng)
# ✅ Cắt timeline 5: Throwing things | frame_id 25560 → 27420 (1860 dòng)
# ✅ Cắt timeline 6: Eating snacks | frame_id 27930 → 35400 (7470 dòng)
# ✅ Cắt timeline 7: Attacking | frame_id 35970 → 38400 (2430 dòng)
# ✅ Cắt timeline 8: Walking | frame_id 38550 → 45750 (7200 dòng)
# ✅ Cắt timeline 9: Head banging | frame_id 46050 → 47820 (1770 dòng)
# ✅ Cắt timeline 10: Sitting quietly | frame_id 48030 → 55170 (7140 dòng)
# ✅ Cắt timeline 11: Biting | frame_id 55260 → 58140 (2880 dòng)
# ✅ Cắt timeline 12: Using phone | frame_id 58380 → 63750 (5370 dòng)
# ✅ Cắt timeline 13: Throwing things | frame_id 63960 → 66570 (2610 dòng)
# ✅ Cắt timeline 14: Eating snacks | frame_id 66960 → 74160 (7200 dòng)
# ✅ Cắt timeline 15: Attacking | frame_id 74580 → 76560 (1980 dòng)
#
# ✅ Đã lưu tổng cộng 72570 dòng vào file: keypoints_cut_by_frame_id.csv

# %%
import pandas as pd
import numpy as np

# Đọc dữ liệu
df_cut['Action Label'] = df_cut['Action Label'].fillna('Unknown').astype(str)
y_all = df_cut['Action Label'].values

# Loại bỏ cột frame_id khỏi features
feature_cols = [col for col in df_cut.columns if col not in ['frame_id', 'Action Label']]
X_all = df_cut[feature_cols].values

sequence_length = 30  # 30 frame = 1s

X_seq_avg = []
y_seq_majority = []
seconds_list = []

for idx, i in enumerate(range(0, len(X_all) - sequence_length + 1, sequence_length)):
    # Trung bình từng cột feature
    avg_features = np.mean(X_all[i:i+sequence_length], axis=0)
    X_seq_avg.append(avg_features)
    
    # Majority voting nhãn
    labels_in_seq = y_all[i:i+sequence_length]
    unique_labels, counts = np.unique(labels_in_seq, return_counts=True)
    majority_label = unique_labels[np.argmax(counts)]
    y_seq_majority.append(majority_label)
    
    # Seconds = chỉ số đoạn (giây)
    #seconds_list.append(idx)

# Chuyển sang DataFrame
df_new = pd.DataFrame(X_seq_avg, columns=feature_cols)
#df_new['Seconds'] = seconds_list
df_new['Action Label'] = y_seq_majority

print(df_new.shape)
print(df_new.head())
df_new.to_csv('per_second_cut_1.csv', index=False)
# Out:
# (2419, 35)
#        nose_x      nose_y  left_eye_x  left_eye_y  right_eye_x  right_eye_y  \
# 0  516.450000  265.083333  520.100000  257.191667   518.083333   257.004167
# 1  326.020833  277.883333  329.508333  271.516667   328.570833   271.183333
# 2  153.764583  300.666667  161.093750  292.316667   154.585417   292.366667
# 3   78.643750  314.616667   91.550000  302.525000    64.617708   304.666667
# 4  254.229167  298.783333  257.966667  285.566667   235.545833   289.266667
#
#    left_ear_x  left_ear_y  right_ear_x  right_ear_y  ...  right_hip_y  \
# 0  540.008333  262.270833   563.083333   258.266667  ...   440.225000
# 1  346.266667  280.108333   373.600000   274.783333  ...   441.558333
# 2  190.558333  297.900000   187.395833   294.441667  ...   463.325000
# 3  114.677083  306.675000    46.083333   312.225000  ...   525.100000
# 4  263.804167  290.816667   194.918750   303.925000  ...   552.550000
#
#    left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 0   581.183333   533.000000    592.400000    518.733333    607.816667
# 1   392.958333   526.750000    421.375000    511.383333    418.216667
# 2   250.654167   543.383333    257.495833    533.200000    275.933333
# 3   208.200000   596.783333    135.008333    615.400000    237.816667
# 4   350.675000   629.733333    298.866667    655.750000    346.475000
#
#    left_ankle_y  right_ankle_x  right_ankle_y  Action Label
# 0    611.233333     618.000000     592.350000       Walking
# 1    601.666667     448.608333     578.800000       Walking
# 2    610.016667     299.708333     588.283333       Walking
# 3    667.500000     156.608333     681.650000       Walking
# 4    710.150000     316.500000     732.750000       Walking
#
# [5 rows x 35 columns]

# %%
import pandas as pd

def check_frame_continuity(df_cut, frame_col='frame', export_csv=False, output_file='frame_gap_errors.csv'):
    """
    Kiểm tra cột frame có liền mạch không (mỗi frame tăng đều 1).
    
    Với mỗi đoạn nhảy frame, in ra cả 2 dòng (frame trước và sau).
    
    Tham số:
    - df_cut: DataFrame gốc
    - frame_col: Tên cột chứa chỉ số frame (mặc định là 'frame')
    - export_csv: Nếu True, xuất các dòng lỗi ra CSV
    - output_file: Tên file CSV để lưu
    """
    # Tính hiệu giữa các frame liên tiếp
    frame_diff = df_cut[frame_col].diff()

    # Tìm index các dòng không liền mạch (diff khác 1), bỏ dòng đầu vì diff NaN
    gap_indices = df_cut.index[frame_diff != 1].tolist()
    gap_indices = [idx for idx in gap_indices if idx != 0]

    if not gap_indices:
        print("✅ Frame liền mạch. Không có lỗi.")
        return []

    print(f"❌ Phát hiện {len(gap_indices)} đoạn frame không liền mạch:\n")

    # In ra 2 dòng của từng đoạn ngách quảng
    for idx in gap_indices:
        prev_idx = idx - 1
        print(f"Đoạn lỗi tại index {prev_idx} và {idx}:")
        print(df_cut.iloc[[prev_idx, idx]])
        print("-" * 60)

    if export_csv:
        # Lấy cả 2 dòng (trước và sau) của từng lỗi
        rows_to_export = df_cut.iloc[[idx - 1 for idx in gap_indices] + gap_indices]
        rows_to_export.to_csv(output_file, index=False)
        print(f"\n✅ Đã lưu các đoạn lỗi vào file: {output_file}")

    return gap_indices

# Cách sử dụng:

# Đọc file CSV
df_cut = pd.read_csv('keypoints_cut_by_frame_id_3.csv')

# Gọi hàm kiểm tra
check_frame_continuity(df_cut, frame_col='frame_id', export_csv=True, output_file='frame_gap_errors.csv')
# Out:
# ❌ Phát hiện 16 đoạn frame không liền mạch:
#
# Đoạn lỗi tại index 18239 và 18240:
#        frame_id  nose_x  nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 18239     18240   538.0  435.50       546.0     430.000        540.5
# 18240     18781   911.0  142.25       911.5     134.375        916.0
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 18239        427.0       575.0      440.50        567.0  ...       598.00
# 18240        134.0       917.5      140.75        970.0  ...       392.25
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 18239        507.0        641.0        506.25         581.0         479.5
# 18240        902.5        496.0        976.00         516.0         888.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y  Action Label
# 18239         624.0          497.5          622.0  Head banging
# 18240         596.5          977.0          653.5       Walking
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 37439 và 37440:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 37439     37980   661.0  163.625       661.5     151.875        648.0
# 37440     38311   648.0  158.375       651.5     149.125        636.5
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 37439      154.750       652.0     155.875        614.0  ...       397.25
# 37440      148.125       652.0     155.250        604.0  ...       387.50
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 37439        693.5        513.0         636.0         516.5         701.5
# 37440        670.0        503.0         611.0         507.5         675.5
#
#        left_ankle_y  right_ankle_x  right_ankle_y     Action Label
# 37439         625.5          639.5          623.0    Eating snacks
# 37440         602.0          617.0          613.0  Throwing things
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 38369 và 38370:
#        frame_id  nose_x  nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 38369     39240  492.75  192.25       502.5       179.0       479.25
# 38370     39301  500.25  569.50       513.5       562.5       486.75
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 38369        183.0       523.5      171.25        467.0  ...        407.5
# 38370        563.0       536.0      525.00        463.0  ...        528.0
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 38369        604.5        516.0        502.50         530.0         622.0
# 38370        574.5        597.5        479.25         607.0         570.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y     Action Label
# 38369         617.0         478.75          649.0  Throwing things
# 38370         651.0         501.75          662.5  Sitting quietly
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 48269 và 48270:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 48269     49200   607.5  482.000       617.0      472.75        602.0
# 48270     49651   877.5  134.875       880.5      125.50        864.5
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 48269       471.25       645.0     464.000        599.0  ...       593.50
# 48270       125.75       879.0     134.125        827.0  ...       396.75
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 48269        724.5        632.5         573.0         643.5         597.0
# 48270        866.0        519.0         789.0         521.0         861.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y     Action Label
# 48269         700.5          710.0          663.5  Sitting quietly
# 48270         626.0          774.0          635.0        Attacking
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 49949 và 49950:
#        frame_id  nose_x  nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 49949     51330   726.0  145.25       736.5     134.375        712.0
# 49950     51481   756.0  413.75       763.0     404.500        744.5
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 49949        137.5       755.5       144.0        698.0  ...        403.0
# 49950        407.0       774.0       407.5        730.5  ...        548.0
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 49949        795.0        533.0         712.5         532.0         810.0
# 49950        809.0        565.0         704.0         528.5         743.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y     Action Label
# 49949         634.5          724.0          637.5        Attacking
# 49950         675.0          708.0          660.5  Sitting quietly
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 62969 và 62970:
#        frame_id  nose_x  nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 62969     64500   729.0   456.5       737.0      445.00        717.0
# 62970     64711   793.0   145.5       807.0      134.25        794.0
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 62969       446.50       748.0     445.500        699.5  ...        575.0
# 62970       132.25       847.5     148.125        819.0  ...        415.0
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 62969        798.0        619.0         638.5         625.5         672.0
# 62970        886.0        574.5         802.5         538.0         901.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y  Action Label
# 62969         663.0          742.0          641.0        Biting
# 62970         710.5          817.5          640.5       Walking
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 67559 và 67560:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 67559     69300   526.0  524.500       528.0     515.000        513.5
# 67560     69571   704.0  149.625       701.0     138.125        695.0
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 67559        525.0       532.0     473.000       478.25  ...        486.5
# 67560        139.0       668.0     144.125       664.00  ...        440.0
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 67559        628.5        593.5         538.0         607.5         620.0
# 67560        664.0        538.0         676.0         575.0         627.5
#
#        left_ankle_y  right_ankle_x  right_ankle_y     Action Label
# 67559         723.0          555.0          725.5          Walking
# 67560         636.5          684.5          712.0  Throwing things
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 69539 và 69540:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 69539     71550   562.0  149.375       556.5      139.25        550.0
# 69540     71641   559.5  167.750       558.0      160.50        562.5
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 69539       141.75       523.5      150.75        521.5  ...       418.00
# 69540       160.50       560.5      165.25        606.0  ...       368.25
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 69539        542.0        532.0         597.0         543.0         554.5
# 69540        625.0        495.5         654.5         481.0         654.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y     Action Label
# 69539         642.5          519.0          679.0  Throwing things
# 69540         613.0          661.0          597.0     Head banging
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 71279 và 71280:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 71279     73380   533.0  174.375       541.0     167.625        525.0
# 71280     73471   727.5  142.500       732.0     133.500        714.5
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 71279       166.50       551.5     173.250        513.5  ...       349.25
# 71280       131.25       733.0     144.875        678.0  ...       411.00
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 71279        588.0        435.5         553.0         431.5         606.5
# 71280        748.0        523.5         689.5         551.0         722.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y  Action Label
# 71279         524.0          564.5          506.0  Head banging
# 71280         613.0          697.5          678.0     Attacking
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 81209 và 81210:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 81209     83400   670.0  148.500       679.5     142.375        658.0
# 81210     83431   718.5  161.625       728.5     153.125        709.0
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 81209      141.625       691.0     158.875        639.5  ...        381.5
# 81210      150.500       737.5     161.250        688.5  ...        372.5
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 81209        703.0       495.25         637.0         499.5         704.5
# 81210        717.5       492.50         648.0         486.5         713.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y  Action Label
# 81209         595.0          636.5          606.0        Biting
# 81210         593.0          637.0          589.0   Using phone
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 87029 và 87030:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 87029     89250   637.5  181.750       646.5      171.50        631.0
# 87030     89401   579.5  155.375       576.5      144.75        572.0
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 87029      171.875       678.0     162.000        628.5  ...       382.00
# 87030      144.750       553.5     151.875        545.0  ...       426.75
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 87029        701.0        508.0         637.0         505.0         709.0
# 87030        588.0        555.0         559.5         562.0         537.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y     Action Label
# 87029         614.5          639.0          619.0      Using phone
# 87030         667.0          546.5          691.0  Throwing things
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 87779 và 87780:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 87779     90150   616.5  153.375       614.0     143.750        604.5
# 87780     90451   542.5  157.750       548.0     153.375        545.0
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 87779      146.625       608.0     150.750        576.5  ...       387.50
# 87780      152.250       560.0     166.875        586.0  ...       349.75
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 87779        630.0        487.0         587.5        498.25         633.0
# 87780        596.5        446.0         571.0        431.50         623.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y     Action Label
# 87779         575.5          562.5         606.00  Throwing things
# 87780         537.0          567.0         509.25     Head banging
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 88859 và 88860:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 88859     91530  502.25  177.625       512.0     169.375       497.75
# 88860     95701  685.50  465.500       694.0     454.000       674.50
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 88859      168.875       533.0     173.875        494.0  ...       345.75
# 88860      456.500       708.5     449.750        662.0  ...       589.50
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 88859        534.5       439.25         546.0         436.0         543.0
# 88860        775.0       613.50         622.0         613.5         650.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y   Action Label
# 88859         527.5          559.5          518.0   Head banging
# 88860         674.5          751.0          655.5  Eating snacks
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 89939 và 89940:
#        frame_id  nose_x  nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 89939     96780   677.0   475.0       681.5      460.50        663.5
# 89940    101341   647.5   467.0       657.0      459.75        643.5
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 89939       469.50       693.5       449.0        650.0  ...        583.0
# 89940       457.25       686.0       455.5        643.5  ...        581.5
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 89939        777.5        617.0         621.0         613.5         649.5
# 89940        775.0        613.0         618.0         618.0         652.5
#
#        left_ankle_y  right_ankle_x  right_ankle_y   Action Label
# 89939         673.5          751.0          652.0  Eating snacks
# 89940         676.0          746.0          649.0         Biting
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 92939 và 92940:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 92939    104340   711.5  500.000       719.0     487.750        699.0
# 92940    104761   901.5  126.125       894.5     117.375        892.0
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 92939      491.000       728.0     476.500        677.5  ...       587.50
# 92940      119.625       852.0     131.625        872.0  ...       375.25
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 92939        773.5        619.0         613.5         628.0         641.0
# 92940        846.0        500.5         870.0         509.5         828.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y  Action Label
# 92939         682.0          749.0          651.0        Biting
# 92940         611.0          834.0          631.0     Attacking
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
# Đoạn lỗi tại index 96599 và 96600:
#        frame_id  nose_x   nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 96599    108420   514.0  177.250       522.5     169.125       507.75
# 96600    108541   746.0  140.625       757.5     130.250       732.00
#
#        right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_y  \
# 96599      169.500       540.5      173.50       502.25  ...       347.50
# 96600      130.375       773.0      143.25       712.00  ...       416.25
#
#        left_knee_x  left_knee_y  right_knee_x  right_knee_y  left_ankle_x  \
# 96599        564.0        436.5         546.0         432.5         572.0
# 96600        780.0        553.5         698.5         557.0         786.0
#
#        left_ankle_y  right_ankle_x  right_ankle_y  Action Label
# 96599         523.0          559.0          502.5  Head banging
# 96600         672.0          698.0          686.0   Using phone
#
# [2 rows x 36 columns]
# ------------------------------------------------------------
#
# ✅ Đã lưu các đoạn lỗi vào file: frame_gap_errors.csv
# [18240,
#  37440,
#  38370,
#  48270,
#  49950,
#  62970,
#  67560,
#  69540,
#  71280,
#  81210,
#  87030,
#  87780,
#  88860,
#  89940,
#  92940,
#  96600]
